# %% [markdown]
# # Initial data analysis and Linear Regression

# %% [markdown]
# This assignment is dedicated to Linear regression. By focusing on prediction different features of football players you understand the mathematics behind it and see the usefulness of main data analysis libraries.

# %% [markdown]
# **Materials**
# - [Documentation](http://docs.scipy.org/doc/) libraries Numpy and SciPy
# - [Documentation](http://matplotlib.org/) library Matplotlib
# - [Documentation](http://pandas.pydata.org/pandas-docs/stable/tutorials.html) library Pandas
# - [Pandas Cheat Sheet](http://www.analyticsvidhya.com/blog/2015/07/11-steps-perform-data-analysis-pandas-python/)
# - [Documentation](http://stanford.edu/~mwaskom/software/seaborn/) library Seaborn
#
# **Resources**
# - In this notebook we will use *FIFA 19 complete player dataset* which is taken from [here](https://www.kaggle.com/karangadiya/fifa19)

# %% [markdown]
# ## Part 1. Initial data analysis with Pandas

# %% [markdown]
# Importing libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %matplotlib inline

# %% [markdown]
# Load the data. Table *data.csv* should be in the same directory as this notebook.

# %%
data = pd.read_csv("data.csv", index_col='ID')

# %% [markdown]
# The first thing you need to do with a dataframe after loading is to look at first few records. This way you can make sure that you have parsed it correctly. Moreover, you can get acquainted with the data, look at the features and their type (categorical, numerical, text ...).
#
# They you may check whether the data has missing values inside. Depending on the problem type and percentage of missing values you can either fill them with some value or drop columns/rows having null values.
#
# After that you may want to look closer at some features. You can draw a histogram for defining a feature distribution (normal, power or some other). Also with the help of histogram you can find values which are really differ from the rest, we call them **outliers**. Histograms can be plotted by *hist* method of Pandas DataFrame.
#
# **Example 1** Let's look at first 5 rows of data using method *head* for DataFrame data.

# %%
data.head()
# Out:
#         Unnamed: 0               Name  Age  \
# ID
# 158023           0           L. Messi   31
# 20801            1  Cristiano Ronaldo   33
# 190871           2          Neymar Jr   26
# 193080           3             De Gea   27
# 192985           4       K. De Bruyne   27
#
#                                                  Photo Nationality  \
# ID
# 158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 20801    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                        Flag  Overall  Potential  \
# ID
# 158023  https://cdn.sofifa.org/flags/52.png       94         94
# 20801   https://cdn.sofifa.org/flags/38.png       94         94
# 190871  https://cdn.sofifa.org/flags/54.png       92         93
# 193080  https://cdn.sofifa.org/flags/45.png       91         93
# 192985   https://cdn.sofifa.org/flags/7.png       91         92
#
#                        Club                                     Club Logo  \
# ID
# 158023         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 20801              Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 190871  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 193080    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 192985      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
#           Value   Wage  Special Preferred Foot  International Reputation  \
# ID
# 158023  €110.5M  €565K     2202           Left                       5.0
# 20801      €77M  €405K     2228          Right                       5.0
# 190871  €118.5M  €290K     2143          Right                       5.0
# 193080     €72M  €260K     1471          Right                       4.0
# 192985    €102M  €355K     2281          Right                       4.0
#
#         Weak Foot  Skill Moves       Work Rate   Body Type Real Face Position  \
# ID
# 158023        4.0          4.0  Medium/ Medium       Messi       Yes       RF
# 20801         4.0          5.0       High/ Low  C. Ronaldo       Yes       ST
# 190871        5.0          5.0    High/ Medium      Neymar       Yes       LW
# 193080        3.0          1.0  Medium/ Medium        Lean       Yes       GK
# 192985        5.0          4.0      High/ High      Normal       Yes      RCM
#
#         Jersey Number        Joined Loaned From Contract Valid Until Height  \
# ID
# 158023           10.0   Jul 1, 2004         NaN                 2021    5'7
# 20801             7.0  Jul 10, 2018         NaN                 2022    6'2
# 190871           10.0   Aug 3, 2017         NaN                 2022    5'9
# 193080            1.0   Jul 1, 2011         NaN                 2020    6'4
# 192985            7.0  Aug 30, 2015         NaN                 2023   5'11
#
#         Weight    LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# ID
# 158023  159lbs  88+2  88+2  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2
# 20801   183lbs  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3
# 190871  150lbs  84+3  84+3  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3
# 193080  168lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  154lbs  82+3  82+3  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3
#
#          RAM    LM   LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB  \
# ID
# 158023  93+2  91+2  84+2  84+2  84+2  91+2  64+2  61+2  61+2  61+2  64+2
# 20801   88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 190871  89+3  88+3  81+3  81+3  81+3  88+3  65+3  60+3  60+3  60+3  65+3
# 193080   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  88+3  88+3  87+3  87+3  87+3  88+3  77+3  77+3  77+3  77+3  77+3
#
#           LB   LCB    CB   RCB    RB  Crossing  Finishing  HeadingAccuracy  \
# ID
# 158023  59+2  47+2  47+2  47+2  59+2      84.0       95.0             70.0
# 20801   61+3  53+3  53+3  53+3  61+3      84.0       94.0             89.0
# 190871  60+3  47+3  47+3  47+3  60+3      79.0       87.0             62.0
# 193080   NaN   NaN   NaN   NaN   NaN      17.0       13.0             21.0
# 192985  73+3  66+3  66+3  66+3  73+3      93.0       82.0             55.0
#
#         ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# ID
# 158023          90.0     86.0       97.0   93.0        94.0         87.0
# 20801           81.0     87.0       88.0   81.0        76.0         77.0
# 190871          84.0     84.0       96.0   88.0        87.0         78.0
# 193080          50.0     13.0       18.0   21.0        19.0         51.0
# 192985          92.0     82.0       86.0   85.0        83.0         91.0
#
#         BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# ID
# 158023         96.0          91.0         86.0     91.0       95.0     95.0
# 20801          94.0          89.0         91.0     87.0       96.0     70.0
# 190871         95.0          94.0         90.0     96.0       94.0     84.0
# 193080         42.0          57.0         58.0     60.0       90.0     43.0
# 192985         91.0          78.0         76.0     79.0       91.0     77.0
#
#         ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# ID
# 158023       85.0     68.0     72.0      59.0       94.0        48.0
# 20801        95.0     95.0     88.0      79.0       93.0        63.0
# 190871       80.0     61.0     81.0      49.0       82.0        56.0
# 193080       31.0     67.0     43.0      64.0       12.0        38.0
# 192985       91.0     63.0     90.0      75.0       91.0        76.0
#
#         Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# ID
# 158023           22.0         94.0    94.0       75.0       96.0     33.0
# 20801            29.0         95.0    82.0       85.0       95.0     28.0
# 190871           36.0         89.0    87.0       81.0       94.0     27.0
# 193080           30.0         12.0    68.0       40.0       68.0     15.0
# 192985           61.0         87.0    94.0       79.0       88.0     68.0
#
#         StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ID
# 158023            28.0           26.0       6.0        11.0       15.0
# 20801             31.0           23.0       7.0        11.0       15.0
# 190871            24.0           33.0       9.0         9.0       15.0
# 193080            21.0           13.0      90.0        85.0       87.0
# 192985            58.0           51.0      15.0        13.0        5.0
#
#         GKPositioning  GKReflexes Release Clause
# ID
# 158023           14.0         8.0        €226.5M
# 20801            14.0        11.0        €127.1M
# 190871           15.0        11.0        €228.1M
# 193080           88.0        94.0        €138.6M
# 192985           10.0        13.0        €196.4M

# %% [markdown]
# Unfortunately the number of columns exceeds the maximum visible default value in Pandas. Use the magic line above to remove this restriction.

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#         Unnamed: 0               Name  Age  \
# ID
# 158023           0           L. Messi   31
# 20801            1  Cristiano Ronaldo   33
# 190871           2          Neymar Jr   26
# 193080           3             De Gea   27
# 192985           4       K. De Bruyne   27
#
#                                                  Photo Nationality  \
# ID
# 158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 20801    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                        Flag  Overall  Potential  \
# ID
# 158023  https://cdn.sofifa.org/flags/52.png       94         94
# 20801   https://cdn.sofifa.org/flags/38.png       94         94
# 190871  https://cdn.sofifa.org/flags/54.png       92         93
# 193080  https://cdn.sofifa.org/flags/45.png       91         93
# 192985   https://cdn.sofifa.org/flags/7.png       91         92
#
#                        Club                                     Club Logo  \
# ID
# 158023         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 20801              Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 190871  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 193080    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 192985      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
#           Value   Wage  Special Preferred Foot  International Reputation  \
# ID
# 158023  €110.5M  €565K     2202           Left                       5.0
# 20801      €77M  €405K     2228          Right                       5.0
# 190871  €118.5M  €290K     2143          Right                       5.0
# 193080     €72M  €260K     1471          Right                       4.0
# 192985    €102M  €355K     2281          Right                       4.0
#
#         Weak Foot  Skill Moves       Work Rate   Body Type Real Face Position  \
# ID
# 158023        4.0          4.0  Medium/ Medium       Messi       Yes       RF
# 20801         4.0          5.0       High/ Low  C. Ronaldo       Yes       ST
# 190871        5.0          5.0    High/ Medium      Neymar       Yes       LW
# 193080        3.0          1.0  Medium/ Medium        Lean       Yes       GK
# 192985        5.0          4.0      High/ High      Normal       Yes      RCM
#
#         Jersey Number        Joined Loaned From Contract Valid Until Height  \
# ID
# 158023           10.0   Jul 1, 2004         NaN                 2021    5'7
# 20801             7.0  Jul 10, 2018         NaN                 2022    6'2
# 190871           10.0   Aug 3, 2017         NaN                 2022    5'9
# 193080            1.0   Jul 1, 2011         NaN                 2020    6'4
# 192985            7.0  Aug 30, 2015         NaN                 2023   5'11
#
#         Weight    LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# ID
# 158023  159lbs  88+2  88+2  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2
# 20801   183lbs  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3
# 190871  150lbs  84+3  84+3  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3
# 193080  168lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  154lbs  82+3  82+3  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3
#
#          RAM    LM   LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB  \
# ID
# 158023  93+2  91+2  84+2  84+2  84+2  91+2  64+2  61+2  61+2  61+2  64+2
# 20801   88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 190871  89+3  88+3  81+3  81+3  81+3  88+3  65+3  60+3  60+3  60+3  65+3
# 193080   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  88+3  88+3  87+3  87+3  87+3  88+3  77+3  77+3  77+3  77+3  77+3
#
#           LB   LCB    CB   RCB    RB  Crossing  Finishing  HeadingAccuracy  \
# ID
# 158023  59+2  47+2  47+2  47+2  59+2      84.0       95.0             70.0
# 20801   61+3  53+3  53+3  53+3  61+3      84.0       94.0             89.0
# 190871  60+3  47+3  47+3  47+3  60+3      79.0       87.0             62.0
# 193080   NaN   NaN   NaN   NaN   NaN      17.0       13.0             21.0
# 192985  73+3  66+3  66+3  66+3  73+3      93.0       82.0             55.0
#
#         ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# ID
# 158023          90.0     86.0       97.0   93.0        94.0         87.0
# 20801           81.0     87.0       88.0   81.0        76.0         77.0
# 190871          84.0     84.0       96.0   88.0        87.0         78.0
# 193080          50.0     13.0       18.0   21.0        19.0         51.0
# 192985          92.0     82.0       86.0   85.0        83.0         91.0
#
#         BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# ID
# 158023         96.0          91.0         86.0     91.0       95.0     95.0
# 20801          94.0          89.0         91.0     87.0       96.0     70.0
# 190871         95.0          94.0         90.0     96.0       94.0     84.0
# 193080         42.0          57.0         58.0     60.0       90.0     43.0
# 192985         91.0          78.0         76.0     79.0       91.0     77.0
#
#         ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# ID
# 158023       85.0     68.0     72.0      59.0       94.0        48.0
# 20801        95.0     95.0     88.0      79.0       93.0        63.0
# 190871       80.0     61.0     81.0      49.0       82.0        56.0
# 193080       31.0     67.0     43.0      64.0       12.0        38.0
# 192985       91.0     63.0     90.0      75.0       91.0        76.0
#
#         Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# ID
# 158023           22.0         94.0    94.0       75.0       96.0     33.0
# 20801            29.0         95.0    82.0       85.0       95.0     28.0
# 190871           36.0         89.0    87.0       81.0       94.0     27.0
# 193080           30.0         12.0    68.0       40.0       68.0     15.0
# 192985           61.0         87.0    94.0       79.0       88.0     68.0
#
#         StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ID
# 158023            28.0           26.0       6.0        11.0       15.0
# 20801             31.0           23.0       7.0        11.0       15.0
# 190871            24.0           33.0       9.0         9.0       15.0
# 193080            21.0           13.0      90.0        85.0       87.0
# 192985            58.0           51.0      15.0        13.0        5.0
#
#         GKPositioning  GKReflexes Release Clause
# ID
# 158023           14.0         8.0        €226.5M
# 20801            14.0        11.0        €127.1M
# 190871           15.0        11.0        €228.1M
# 193080           88.0        94.0        €138.6M
# 192985           10.0        13.0        €196.4M

# %% [markdown]
# Much better now.
#
# **Example 2** Print total player number and top-10 columns containing the most number of null values.

# %%
print(f"Total number of players in dataset {data.shape[0]}")
# Out:
# Total number of players in dataset 18207

# %%
from tabulate import tabulate

top = 10
print(tabulate(
    sorted(list(zip(data.columns, data.isnull().sum(), data.isnull().sum() / data.shape[0] * 100)), key=lambda x: -x[2])[:top], 
    headers=['col_name', 'null_cnt', 'null_perc']))
# Out:
# col_name       null_cnt    null_perc
# -----------  ----------  -----------
# Loaned From       16943      93.0576
# LS                 2085      11.4516
# ST                 2085      11.4516
# RS                 2085      11.4516
# LW                 2085      11.4516
# LF                 2085      11.4516
# CF                 2085      11.4516
# RF                 2085      11.4516
# RW                 2085      11.4516
# LAM                2085      11.4516

# %% [markdown]
# **Example 3**. Let's built a histogram of weight distribution in kgs from footbal players data. Follow steps:
# - Extract weight value from string (column Weight).
# - Convert *Weight* column to float type.
# - Get rid of null values in weight column, use median column value instead of them.
# - Convert pounds to kilograms
# - Finally use method *hist* for DataFrame *data* with arguments *column=Weight* (we look at this feature distribution)

# %%
print(f"Weight column type is '{data['Weight'].dtype}'")
# Out:
# Weight column type is 'object'

# %%
data['Weight_float'] = data['Weight'].str.extract(r'([0-9]+)lbs').astype(float)
data['Weight_float'].fillna(data['Weight_float'].median())
POUND_TO_KILO = 0.454
data['Weight_kg'] = data.apply(lambda row: row['Weight_float'] * POUND_TO_KILO, axis=1)
data.hist(column='Weight_kg', bins=30)
plt.show()

# %% [markdown]
# **Task 1 (1 point)**. Built a histogram of the height distribution in *meters* from footbal player data. Remember that height is in format *feet* '*inches*.  Instead of filling null values with some constant just drop them. Use *.dropna* for specified column.

# %%
# Your code here
data['Height_feet'] = pd.to_numeric(data['Height'].str.split("'", expand=True)[0])
data['Height_inches']  = pd.to_numeric(data['Height'].str.split("'", expand=True)[1])
data['Height_cm'] = data['Height_feet'] * 30.48 + data['Height_inches'] * 2.54
data.drop(columns=['Height_feet', 'Height_inches'], inplace=True)
data.hist(column='Height_cm', bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'Height_cm'}>]], dtype=object)

# %% [markdown]
# Effective way to visualize the relationship between two features is to draw a simple _scatter plot_. The position of each dot on the horizontal and vertical axis indicates values for an individual data point.

# %% [markdown]
# **Example 4.** Visualize the dependence of _Strength_  on _Weight_kg_.

# %%
data.plot.scatter(x='Weight_kg', y='Strength')
plt.title('Dependence of strength on weight')
plt.show()

# %% [markdown]
# One more effective way of initial data analysis is to plot pairwise feature dependencies. That simply combines already considered Scatter plot and a histogram. We create $m \times m$ plots (_m_ is number of features) where pictures on diagonal represent **histograms** and outside the diagonal **scatter_matrix**. That can be done with the help of _scatter_matrix_ Pandas DataFrame method or _pairplot_ in Seaborn.

# %% [markdown]
# **Example 5.**
# Illustrate pairwise dependencies between _ShortPassing_, _Dribbling_, _BallControl_ and _Strength_ features of footbal players.

# %%
sns.pairplot(data[['ShortPassing', 'Dribbling', 'BallControl', 'Strength']])

# %% [markdown]
# Histograms and scatter plots are good for continuous (numerical) features. Distribution of data by categorical features (that have a fixed number of possible values) can be represented with **bar charts**.

# %% [markdown]
# **Example 6.** Show distribution of players by age groups (under 20 yo. _young_, between 20-30 _mature_, over 30 yo. _masters_)

# %%
data['age_group'] = data.apply(lambda x: 'young' if x['Age'] < 20 else 'mature' if x['Age'] <= 30 else 'masters', axis=1)
distr = data.groupby('age_group').count().max(axis=1)[['young', 'mature', 'masters']]

plt.bar(distr.index, distr.values)
plt.ylabel('Number of players')
plt.title('Distribution of players across age groups')
plt.show()

# %% [markdown]
# Really often it is necessary to explore the distribution of some numerical feature based on the value of categorical one. Here comes the _boxplot_ of Seaborn library, which can show statistics of numerical features (mean, quantiles) by different value of categorical feature. Boxplot can also help to detect **outliers** - values that significantly differ from the rest. More detailed explanation [here](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51).

# %% [markdown]
# **Example 7.** Show _SprintSpeed_ statistics across different age groups.

# %% [markdown]
# _Hint_: in order to prevent printing the service information and make our pictures more attractive we can write `;` in the end of last line.

# %%
sns.boxplot(x='age_group', y='SprintSpeed', data=data);

# %% [markdown]
# ## Part 2. Minimizing Mean Squared Error. Linear Regression

# %% [markdown]
# We are going to predict target numerical variable $y$ for _n_ samples with the help of $x_1, x_2, ..., x_m$ _m_ features under the assumption of _liner dependence_ existence between features and target, i.e.
# $$\hat{y} = w_0 + w_1 * x_1 + w_2 * x_2 + ... + w_m * x_m$$
# so that Mean Squared Error between $y$ and $\hat{y}$ was the lowest possible
# $$MSE = \frac{1}{n}\sum_{i=1}^n {(y_i - \hat{y})}^2 -> min_{w_0, w_1, w_2, ...w_m}$$
# where $w_0$ is "free" weight component called **intercept** and $(w_1, w_2, ... w_n)$ is a **vector of coefficients**.

# %% [markdown]
#  ### Part 2.1 Linear Regression with one variable

# %% [markdown]
# Just to understand the basic principles, let's try to predict _BallControl_ score based on the _Dribbling_ score for every player. Simple Linear Regression with one feature.
# $$BallControl = w_0 + w_1 * Dribbling$$

# %% [markdown]
# We are going to do real data science, aren't we? So let us split the available data into train and test samples. We let our model see only the train data, then we can measure it's quality on test sample.

# %%
from sklearn.model_selection import train_test_split

data.fillna({'BallControl': data['BallControl'].mean(), 'Dribbling': data['Dribbling'].mean()}, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(data['Dribbling'].values, data['BallControl'].values, train_size=0.8)
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# %% [markdown]
# To illustrate the approach, let's use Ridge model from sklearn with _regularization_ param alpha=0. What does it mean and what it if for we will find out later on in this course. But for now I require avoiding regularization by setting regularization param to zero.

# %%
from sklearn.linear_model import Ridge

lr = Ridge(alpha=0)
lr.fit(X=X_train, y=y_train)
# Out:
# Ridge(alpha=0)

# %%
print(f'w_0 = {lr.intercept_}, w_1 = {lr.coef_[0]}')
# Out:
# w_0 = 12.477651971388148, w_1 = 0.8290521000833517

# %%
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

# %%
data['predicted_BallControl'] = lr.predict(data['Dribbling'].values.reshape(-1, 1))
data[['Name', 'Dribbling', 'BallControl', 'predicted_BallControl']].head()
# Out:
#                      Name  Dribbling  BallControl  predicted_BallControl
# ID
# 158023           L. Messi       97.0         96.0              92.895706
# 20801   Cristiano Ronaldo       88.0         94.0              85.434237
# 190871          Neymar Jr       96.0         95.0              92.066654
# 193080             De Gea       18.0         42.0              27.400590
# 192985       K. De Bruyne       86.0         91.0              83.776133

# %% [markdown]
# Right now we have predictions for train and test samples. How about measure the quality of the model?

# %% [markdown]
# **Task 2 (0.5 point).** Write your own function for MSE calculation using the formula above. Calculate train and test MSE, compare to built-in method (_sklearn.metrics.mean_squared_error_)

# %%
def mse(y_true, y_pred):    
    error = np.mean((y_true - y_pred)**2) 
    return error

# %%
from sklearn.metrics import mean_squared_error

assert mean_squared_error(y_train, y_pred_train) == mse(y_train, y_pred_train)
assert mean_squared_error(y_test, y_pred_test) == mse(y_test, y_pred_test)

# %%
print(f'Train MSE {mse(y_train, y_pred_train)}, test MSE {mse(y_test, y_pred_test)}')
# Out:
# Train MSE 33.42661752152131, test MSE 30.673147187923654

# %% [markdown]
# **Task 3 (1.5 points).** Visualize the dependence of **test** _BallControl_ predictions and real _BallControl_ score on _Dribbling_ score. Don't forget to add axis and plot names!

# %%
# Your code here
plt.scatter(X_test, y_test, label='True score')
plt.scatter(X_test, y_pred_test, label='Predicted score')
plt.xlabel('Dribbling')
plt.ylabel('BallControl')
plt.legend()

# %% [markdown]
# ### Part 2.2 Linear regression with many variables

# %% [markdown]
# **Task 4 (5 points).** Implement your own Linear Regression class for any number of input features and settable boolean parameter *fit_intercept*.

# %% [markdown]
# In this task you will work with _optimize_ module of [_scipy_](https://docs.scipy.org/doc/scipy/reference/) open-source library for mathematics, science, and engineering. You will need a function [_least_squares_](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.least_squares.html) that finds a coefficients for linear regression by minimizing the sum of the squares of the residuals (which is equivalent to MSE minimizing). More information about least squares approach [here](https://en.wikipedia.org/wiki/Least_squares). <br><br>
# Even though this function has many parameters, you need only a few of them to complete the task (the rest will be filled in with default values automatically).
# - **fun** computes a vector of residuals given weights, features and target, we provide you a function template _compute_residuals_
# - **x0** this is an initial weights vector. You can either pass a vector of zeros[n_features] or fill in randomly.
# - **args** are fixed arguments to _fun_ function (which we are not going to optimize). In that particular case you will need to pass X and y.
#
#
# You can access optimized weights by accessing the field **.x** of object which returns by this function.

# %%
def compute_residuals(w, X, y):
    """
    Compute residuals when predicting y_hat as matrix product of X and transposed w
    :param w: linear regression weights, numpy.ndarrya: float64[num_features]
    :param X: training features, numpy.ndarray: float64[num_samples, num_features]
    :param y: training target, numpy.ndarray: float64[num_samples]
    :returns: vector of residuals (y_i_hat - y_i) for each sample_i in X
    """
    #residuals = 
    return y - X.dot(w)

# %%
from sklearn.base import BaseEstimator
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted
from scipy.optimize import least_squares

class LinearRegression(BaseEstimator):
    def __init__(self, fit_intercept=True):
        self.fit_intercept = fit_intercept
    
    def fit(self, X, y):
        """
        fit model weights given input features and target
        :param X: training features, numpy.ndarray: numeric[num_samples, num_features]
        :param y: training target, numpy.ndarray: numeric[num_samples]
        :returns: linear predictor with fitted weights so that train MSE is the lowest possible
        :note: weights: numpy.ndarray: float64[num_features] stored as class field

        """
        
        # Check that X and y have correct shape
        X, y = check_X_y(X, y)
        
        # Save train data information. Necessary for following the uniform API
        self.X_ = X
        self.y_ = y
        self.n_features_in_ = X.shape[1]
        
        # Copy arrays and cast them to uniform type
        X_train = X.astype('float64')
        y_train = y.astype('float64')
        
        # Add dummy column of ones to X_train if we want to train an intercept - last component of future weight vector
        if self.fit_intercept:
            X_train = np.column_stack((X_train, np.ones(X_train.shape[0])))
        
        # Your code here.
        # Just follow the suggested steps: create initial weights vector,
        # apply least_squares optimizer passing the parameters described above
        # and finally extract optimized weights.
        # Remember: you need to distinguish coefficients from intercept when fit_intercept=True
        # Инициируем веса
        self.coef_ = np.zeros(self.n_features_in_)
        self.intercept_ = np.zeros(1)
        if self.fit_intercept:
            w = np.concatenate((self.coef_, self.intercept_), axis=None)
        else:
            w = self.coef_
        
        # Находим оптимальные
        w = least_squares(compute_residuals, w, args=(X_train, y_train)).x
        
        # Записываем в модель
        if self.fit_intercept:
            self.coef_ = w[:-1]
            self.intercept_ = w[-1]
        else:
            self.coef_ = w
    
        # Return the classifier
        return self
        
    def predict(self, X):
        # Check is fit had been called
        check_is_fitted(self)
        
        # Input validation
        X = check_array(X)
        
        return X.dot(self.coef_) + self.intercept_

# %%
#Testing area
from sklearn.utils.estimator_checks import check_estimator
from sklearn.linear_model import Ridge

lr = LinearRegression()
ridge = Ridge(alpha=0)
lr_no_intercept = LinearRegression(fit_intercept=False)
ridge_no_intercept = Ridge(alpha=0, fit_intercept=False)

#Check compatibility with Sklearn framework and apply some spesific internal tests
check_estimator(lr)
check_estimator(lr_no_intercept)

#Compare model accuracy with Ridge(0) from Sklearn
data.fillna({'BallControl': data['BallControl'].mean()
             , 'Dribbling': data['Dribbling'].mean()
             , 'Strength': data['Strength'].mean()}, inplace=True)
X_sample, y_sample = data[['Dribbling', 'Strength']], data['BallControl']
lr.fit(X_sample, y_sample)
ridge.fit(X_sample, y_sample)
assert np.allclose(lr.predict(X_sample), ridge.predict(X_sample), rtol=1e-03), "Your model with intercept not accurate enough!"
lr_no_intercept.fit(X_sample, y_sample)
ridge_no_intercept.fit(X_sample, y_sample)
assert np.allclose(lr_no_intercept.predict(X_sample), ridge_no_intercept.predict(X_sample), rtol=1e-03), "Your model without intercept not accurate enough!"

# %% [markdown]
# Let's add more features in order to predict Dribbling score more accurately.

# %%
features = ['BallControl', 'ShortPassing', 'Strength', 'Weight_float', 'Weight_kg']
target = 'Dribbling'
for feat in features:
    data.fillna({feat: data[feat].mean()}, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(data[features].values, data[target].values, train_size=0.8, random_state=2)

# %%
lr = Ridge(0)
lr.fit(X=X_train, y=y_train)

y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

print(f'Train MSE {mean_squared_error(y_train, y_pred_train)}, test MSE {mean_squared_error(y_test, y_pred_test)}')
# Out:
# Train MSE 37.67559008657423, test MSE 33.95569626265063

# %%
print(f'w_0 = {lr.intercept_}, w_1, w_2, w_3, w_4, w_5 = {lr.coef_}')
# Out:
# w_0 = 11.854762396379293, w_1, w_2, w_3, w_4, w_5 = [ 1.09358190e+00 -4.75391293e-02 -1.27364934e-01  1.27507005e+07
#  -2.80852436e+07]

# %% [markdown]
# That is not ok, two last weight components are too large, and they vary depending on the run! Although the result seems better our model would behave unexpectadly to the patterns in data it has never seen! Large weights and weights instability are the sign of [**overfitting**](https://en.wikipedia.org/wiki/Overfitting).  <br><br>
# According to the definition it is "_the production of an analysis that corresponds too closely or exactly to a particular set of data, and may therefore fail to fit additional data or predict future observations reliably_". But what does it actually mean?

# %% [markdown]
# Assume that we have a player whose weight in kg was calculated with some tiny error, let's say +=1g.

# %%
player = data[features + [target]].iloc[0:2]
player['Predicted_dribbling'] = lr.predict(player[features].values)
player.head()
# Out:
#         BallControl  ShortPassing  Strength  Weight_float  Weight_kg  \
# ID
# 158023         96.0          90.0      59.0         159.0     72.186
# 20801          94.0          81.0      79.0         183.0     83.082
#
#         Dribbling  Predicted_dribbling
# ID
# 158023       97.0            96.208037
# 20801        88.0            90.567459

# %% [markdown]
# Predictions are pretty good if the data is _pure_. Let's add some noise to _Weight_kg_ feature:

# %%
player['Weight_kg'] = player['Weight_kg'] + [-0.001, 0.001]
player['Predicted_dribbling_with_error'] = lr.predict(player[features].values)
player.head()
# Out:
#         BallControl  ShortPassing  Strength  Weight_float  Weight_kg  \
# ID
# 158023         96.0          90.0      59.0         159.0     72.185
# 20801          94.0          81.0      79.0         183.0     83.083
#
#         Dribbling  Predicted_dribbling  Predicted_dribbling_with_error
# ID
# 158023       97.0            96.208037                    28181.451596
# 20801        88.0            90.567459                   -27994.676100

# %% [markdown]
# Predicted dribbling value has changed significantly! Look at how this tiny **1g** error leads to extremly big or small dribbling!

# %% [markdown]
# The reason behind it is strange unstable behaviour is **collinearity** between Weight and Weight_kg features, what means that Weight_kg can be linearly predicted from Weight. As a matter of fact they represent the same essense but in different scales. <br><br>
# **Multicollinearity** describes a more general case, when one feature can be predicted by linear combination of some other features.<br><br>
# Collinearity is really close related to **correlation** - degree to which a pair of variables are linearly related. Collinearity origins from Linear Algebra and Geometry whereas Correlation is a term from Statistics. Anyway all of this three terms refer to **linearly dependent features**, which is really bad for Linear Models.

# %% [markdown]
# But why it is so bad? The main reason is that Linear Regression tries to capture the contribution of each feature to target _independently_, which obviously is not possible in terms of feature multicolliearity.<br><br>
# There are a whole bunch of really interesting thoughts that can help to capture the intuition behind it [here](https://stats.stackexchange.com/questions/1149/is-there-an-intuitive-explanation-why-multicollinearity-is-a-problem-in-linear-r). I'd citate one of the examples provided.<br><br>
# _Assume that two people collaborated and accomplished scientific discovery. It is easy to tell their unique contributions (who did what) when two are totally different persons (one is theory guy and the other is good at experiment), while it is difficult to distinguish their unique influences (coefficients in regression) when they are twins acting similarly._

# %% [markdown]
# There are a few approaches how to prevent overfitting and overcome multicollinearity.
# - Drop features
# - Combine features
# - Regularization
#
#
# Regularization is something we are going to speak about in the next modules. Combining features is problem-specific and could easily trigger a _holy_war_ due to ambiguity of approaches. Let's focus on simpliest - drop one of the features from the correlated pair.<br>
# At first we need to define those pairs of features, **correlation matrix** comes to rescue! Each cell in the table shows the correlation between two variables. We use dataframe in-built method _corr_ in combination with seaborn _heatmap_.

# %%
from seaborn import heatmap

heatmap(data[features].corr(method='pearson'), center=0, square=True)
plt.show()

# %%
features = ['BallControl', 'ShortPassing', 'Strength', 'Weight_kg']
X_train, X_test, y_train, y_test = train_test_split(data[features].values, data[target].values, train_size=0.8, random_state=2)

lr = Ridge(alpha=0)
lr.fit(X=X_train, y=y_train)

player['Predicted_dribbling_with_error'] = lr.predict(player[features].values)
player.head()
# Out:
#         BallControl  ShortPassing  Strength  Weight_float  Weight_kg  \
# ID
# 158023         96.0          90.0      59.0         159.0     72.185
# 20801          94.0          81.0      79.0         183.0     83.083
#
#         Dribbling  Predicted_dribbling  Predicted_dribbling_with_error
# ID
# 158023       97.0            96.208037                       96.208130
# 20801        88.0            90.567459                       90.567307

# %% [markdown]
# ### Part 2.3 Putting all together

# %% [markdown]
# **Task 5 (up to 5 points).** Build a Linear Regression model for _Value_ prediction for every football player and validate it. You **have to** use either your custom Linear Regression class or `sklearn.linear_model.Ridge` with regularization param alpha=0. Steps you need to follow:
# - Extract float number from _Value_ field in DataFrame (**0.5 points**)
# - Сhoose more features that you expect to influence on player _Value_ (at least 10)
# - Plot feature correlation matrix. (**0.5 points**)
# - Drop features that are highly correlated with each other (_abs_(corr) > 0.9) one by one until no correlated pairs left. _Hint_: you may reuse code from Task_9 in HW_1 for automatic correlated pairs selection. (**1.5 points**)
# - Split data into train/test with some proportion (**0.5 points**)
# - Train a model on train dataset, make predictions both for train and test. (**0.5 points**)
# - Measure the model quality in terms of RMSE in train and test samples,  (**0.5 points**)
# - Write a short report about the work done. Why did you take these particular features? Can you find a logical explanation for high correlation of some of your features? Are you satisfied with the quality of predictions? etc. (**1 point**)

# %% [markdown]
# **Penalties**
# - **-1 point** if used a different model besides custom Linear Regression or `sklearn.linear_model.Ridge` with regularization param alpha=0
# - **-0.5 points** if number of selected features BEFORE removal of linearly dependent ones is less than 10.
# - **-0.5 points** if did not remove linearly dependent features before training the model.

# %%
# Your code and a bunch of cool ideas here
data = pd.read_csv("data.csv", index_col='ID')
data.head()
# Out:
#         Unnamed: 0               Name  Age  \
# ID
# 158023           0           L. Messi   31
# 20801            1  Cristiano Ronaldo   33
# 190871           2          Neymar Jr   26
# 193080           3             De Gea   27
# 192985           4       K. De Bruyne   27
#
#                                                  Photo Nationality  \
# ID
# 158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 20801    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                        Flag  Overall  Potential  \
# ID
# 158023  https://cdn.sofifa.org/flags/52.png       94         94
# 20801   https://cdn.sofifa.org/flags/38.png       94         94
# 190871  https://cdn.sofifa.org/flags/54.png       92         93
# 193080  https://cdn.sofifa.org/flags/45.png       91         93
# 192985   https://cdn.sofifa.org/flags/7.png       91         92
#
#                        Club                                     Club Logo  \
# ID
# 158023         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 20801              Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 190871  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 193080    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 192985      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
#           Value   Wage  Special Preferred Foot  International Reputation  \
# ID
# 158023  €110.5M  €565K     2202           Left                       5.0
# 20801      €77M  €405K     2228          Right                       5.0
# 190871  €118.5M  €290K     2143          Right                       5.0
# 193080     €72M  €260K     1471          Right                       4.0
# 192985    €102M  €355K     2281          Right                       4.0
#
#         Weak Foot  Skill Moves       Work Rate   Body Type Real Face Position  \
# ID
# 158023        4.0          4.0  Medium/ Medium       Messi       Yes       RF
# 20801         4.0          5.0       High/ Low  C. Ronaldo       Yes       ST
# 190871        5.0          5.0    High/ Medium      Neymar       Yes       LW
# 193080        3.0          1.0  Medium/ Medium        Lean       Yes       GK
# 192985        5.0          4.0      High/ High      Normal       Yes      RCM
#
#         Jersey Number        Joined Loaned From Contract Valid Until Height  \
# ID
# 158023           10.0   Jul 1, 2004         NaN                 2021    5'7
# 20801             7.0  Jul 10, 2018         NaN                 2022    6'2
# 190871           10.0   Aug 3, 2017         NaN                 2022    5'9
# 193080            1.0   Jul 1, 2011         NaN                 2020    6'4
# 192985            7.0  Aug 30, 2015         NaN                 2023   5'11
#
#         Weight    LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# ID
# 158023  159lbs  88+2  88+2  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2
# 20801   183lbs  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3
# 190871  150lbs  84+3  84+3  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3
# 193080  168lbs   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  154lbs  82+3  82+3  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3
#
#          RAM    LM   LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB  \
# ID
# 158023  93+2  91+2  84+2  84+2  84+2  91+2  64+2  61+2  61+2  61+2  64+2
# 20801   88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 190871  89+3  88+3  81+3  81+3  81+3  88+3  65+3  60+3  60+3  60+3  65+3
# 193080   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 192985  88+3  88+3  87+3  87+3  87+3  88+3  77+3  77+3  77+3  77+3  77+3
#
#           LB   LCB    CB   RCB    RB  Crossing  Finishing  HeadingAccuracy  \
# ID
# 158023  59+2  47+2  47+2  47+2  59+2      84.0       95.0             70.0
# 20801   61+3  53+3  53+3  53+3  61+3      84.0       94.0             89.0
# 190871  60+3  47+3  47+3  47+3  60+3      79.0       87.0             62.0
# 193080   NaN   NaN   NaN   NaN   NaN      17.0       13.0             21.0
# 192985  73+3  66+3  66+3  66+3  73+3      93.0       82.0             55.0
#
#         ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# ID
# 158023          90.0     86.0       97.0   93.0        94.0         87.0
# 20801           81.0     87.0       88.0   81.0        76.0         77.0
# 190871          84.0     84.0       96.0   88.0        87.0         78.0
# 193080          50.0     13.0       18.0   21.0        19.0         51.0
# 192985          92.0     82.0       86.0   85.0        83.0         91.0
#
#         BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# ID
# 158023         96.0          91.0         86.0     91.0       95.0     95.0
# 20801          94.0          89.0         91.0     87.0       96.0     70.0
# 190871         95.0          94.0         90.0     96.0       94.0     84.0
# 193080         42.0          57.0         58.0     60.0       90.0     43.0
# 192985         91.0          78.0         76.0     79.0       91.0     77.0
#
#         ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# ID
# 158023       85.0     68.0     72.0      59.0       94.0        48.0
# 20801        95.0     95.0     88.0      79.0       93.0        63.0
# 190871       80.0     61.0     81.0      49.0       82.0        56.0
# 193080       31.0     67.0     43.0      64.0       12.0        38.0
# 192985       91.0     63.0     90.0      75.0       91.0        76.0
#
#         Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# ID
# 158023           22.0         94.0    94.0       75.0       96.0     33.0
# 20801            29.0         95.0    82.0       85.0       95.0     28.0
# 190871           36.0         89.0    87.0       81.0       94.0     27.0
# 193080           30.0         12.0    68.0       40.0       68.0     15.0
# 192985           61.0         87.0    94.0       79.0       88.0     68.0
#
#         StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ID
# 158023            28.0           26.0       6.0        11.0       15.0
# 20801             31.0           23.0       7.0        11.0       15.0
# 190871            24.0           33.0       9.0         9.0       15.0
# 193080            21.0           13.0      90.0        85.0       87.0
# 192985            58.0           51.0      15.0        13.0        5.0
#
#         GKPositioning  GKReflexes Release Clause
# ID
# 158023           14.0         8.0        €226.5M
# 20801            14.0        11.0        €127.1M
# 190871           15.0        11.0        €228.1M
# 193080           88.0        94.0        €138.6M
# 192985           10.0        13.0        €196.4M

# %%
#Extract float number from Value field in DataFrame (0.5 points)
Value_USD = data['Value'].str.replace('€', '')
# Проверяем что есть только значения с M, K и 0
print(Value_USD[(Value_USD.str.endswith('M') == False)&(Value_USD.str.endswith('K') == False)&(Value_USD != '0')].count())
data['Value_USD'] = Value_USD.apply(lambda x: float(x.partition('M')[0])*1000000 if x.endswith('M') 
                      else float(x.partition('K')[0])*1000)
data['Value_USD']
# Out:
# 0
# ID
# 158023    110500000.0
# 20801      77000000.0
# 190871    118500000.0
# 193080     72000000.0
# 192985    102000000.0
#              ...
# 238813        60000.0
# 243165        60000.0
# 241638        60000.0
# 246268        60000.0
# 246269        60000.0
# Name: Value_USD, Length: 18207, dtype: float64

# %%
#Сhoose more features that you expect to influence on player Value (at least 10)
# Почему бы не взять все числовые признаки. 
numeric_features = data.select_dtypes(include=[np.number]).columns.tolist()
numeric_features.remove('Unnamed: 0')
print(numeric_features)
# Out:
# ['Age', 'Overall', 'Potential', 'Special', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes', 'Value_USD']

# %%
#Plot feature correlation matrix. (0.5 points)
data[numeric_features].corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style  type="text/css" >
# #T_2a90a_row0_col0,#T_2a90a_row1_col1,#T_2a90a_row2_col2,#T_2a90a_row3_col3,#T_2a90a_row4_col4,#T_2a90a_row5_col5,#T_2a90a_row6_col6,#T_2a90a_row7_col7,#T_2a90a_row8_col8,#T_2a90a_row9_col9,#T_2a90a_row10_col10,#T_2a90a_row11_col11,#T_2a90a_row12_col12,#T_2a90a_row13_col13,#T_2a90a_row14_col14,#T_2a90a_row15_col15,#T_2a90a_row16_col16,#T_2a90a_row17_col17,#T_2a90a_row18_col18,#T_2a90a_row19_col19,#T_2a90a_row20_col20,#T_2a90a_row21_col21,#T_2a90a_row22_col22,#T_2a90a_row23_col23,#T_2a90a_row24_col24,#T_2a90a_row25_col25,#T_2a90a_row26_col26,#T_2a90a_row27_col27,#T_2a90a_row28_col28,#T_2a90a_row29_col29,#T_2a90a_row30_col30,#T_2a90a_row31_col31,#T_2a90a_row32_col32,#T_2a90a_row33_col33,#T_2a90a_row34_col34,#T_2a90a_row35_col35,#T_2a90a_row36_col36,#T_2a90a_row37_col37,#T_2a90a_row38_col38,#T_2a90a_row39_col39,#T_2a90a_row40_col40,#T_2a90a_row41_col41,#T_2a90a_row42_col42{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2a90a_row0_col1,#T_2a90a_row5_col16,#T_2a90a_row5_col25,#T_2a90a_row15_col34,#T_2a90a_row16_col21,#T_2a90a_row23_col34,#T_2a90a_row24_col17,#T_2a90a_row28_col19,#T_2a90a_row29_col14,#T_2a90a_row29_col15,#T_2a90a_row33_col36,#T_2a90a_row34_col15,#T_2a90a_row35_col23,#T_2a90a_row42_col8{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_2a90a_row0_col2,#T_2a90a_row0_col7,#T_2a90a_row2_col0,#T_2a90a_row7_col1,#T_2a90a_row7_col4,#T_2a90a_row7_col21,#T_2a90a_row7_col42,#T_2a90a_row17_col37,#T_2a90a_row17_col38,#T_2a90a_row17_col39,#T_2a90a_row17_col40,#T_2a90a_row17_col41,#T_2a90a_row22_col26,#T_2a90a_row37_col3,#T_2a90a_row37_col5,#T_2a90a_row37_col6,#T_2a90a_row37_col8,#T_2a90a_row37_col9,#T_2a90a_row37_col10,#T_2a90a_row37_col11,#T_2a90a_row37_col12,#T_2a90a_row37_col13,#T_2a90a_row37_col14,#T_2a90a_row37_col15,#T_2a90a_row37_col16,#T_2a90a_row37_col17,#T_2a90a_row37_col18,#T_2a90a_row37_col19,#T_2a90a_row37_col20,#T_2a90a_row37_col22,#T_2a90a_row37_col23,#T_2a90a_row37_col24,#T_2a90a_row37_col25,#T_2a90a_row37_col27,#T_2a90a_row37_col28,#T_2a90a_row37_col29,#T_2a90a_row37_col30,#T_2a90a_row37_col31,#T_2a90a_row37_col32,#T_2a90a_row37_col33,#T_2a90a_row37_col34,#T_2a90a_row37_col35,#T_2a90a_row37_col36,#T_2a90a_row38_col3,#T_2a90a_row38_col5,#T_2a90a_row38_col6,#T_2a90a_row38_col8,#T_2a90a_row38_col9,#T_2a90a_row38_col10,#T_2a90a_row38_col11,#T_2a90a_row38_col12,#T_2a90a_row38_col13,#T_2a90a_row38_col14,#T_2a90a_row38_col15,#T_2a90a_row38_col16,#T_2a90a_row38_col17,#T_2a90a_row38_col18,#T_2a90a_row38_col19,#T_2a90a_row38_col20,#T_2a90a_row38_col22,#T_2a90a_row38_col23,#T_2a90a_row38_col24,#T_2a90a_row38_col25,#T_2a90a_row38_col27,#T_2a90a_row38_col28,#T_2a90a_row38_col29,#T_2a90a_row38_col30,#T_2a90a_row38_col31,#T_2a90a_row38_col32,#T_2a90a_row38_col33,#T_2a90a_row38_col34,#T_2a90a_row38_col35,#T_2a90a_row38_col36,#T_2a90a_row39_col3,#T_2a90a_row39_col5,#T_2a90a_row39_col6,#T_2a90a_row39_col8,#T_2a90a_row39_col9,#T_2a90a_row39_col10,#T_2a90a_row39_col11,#T_2a90a_row39_col12,#T_2a90a_row39_col13,#T_2a90a_row39_col14,#T_2a90a_row39_col16,#T_2a90a_row39_col17,#T_2a90a_row39_col18,#T_2a90a_row39_col19,#T_2a90a_row39_col20,#T_2a90a_row39_col22,#T_2a90a_row39_col23,#T_2a90a_row39_col24,#T_2a90a_row39_col25,#T_2a90a_row39_col28,#T_2a90a_row39_col29,#T_2a90a_row39_col30,#T_2a90a_row39_col32,#T_2a90a_row39_col33,#T_2a90a_row39_col34,#T_2a90a_row39_col35,#T_2a90a_row39_col36,#T_2a90a_row40_col3,#T_2a90a_row40_col5,#T_2a90a_row40_col6,#T_2a90a_row40_col8,#T_2a90a_row40_col9,#T_2a90a_row40_col10,#T_2a90a_row40_col11,#T_2a90a_row40_col12,#T_2a90a_row40_col13,#T_2a90a_row40_col14,#T_2a90a_row40_col15,#T_2a90a_row40_col16,#T_2a90a_row40_col17,#T_2a90a_row40_col18,#T_2a90a_row40_col19,#T_2a90a_row40_col20,#T_2a90a_row40_col22,#T_2a90a_row40_col23,#T_2a90a_row40_col25,#T_2a90a_row40_col27,#T_2a90a_row40_col28,#T_2a90a_row40_col29,#T_2a90a_row40_col30,#T_2a90a_row40_col32,#T_2a90a_row40_col34,#T_2a90a_row40_col35,#T_2a90a_row40_col36,#T_2a90a_row41_col3,#T_2a90a_row41_col5,#T_2a90a_row41_col6,#T_2a90a_row41_col8,#T_2a90a_row41_col9,#T_2a90a_row41_col10,#T_2a90a_row41_col11,#T_2a90a_row41_col12,#T_2a90a_row41_col13,#T_2a90a_row41_col14,#T_2a90a_row41_col15,#T_2a90a_row41_col16,#T_2a90a_row41_col17,#T_2a90a_row41_col18,#T_2a90a_row41_col19,#T_2a90a_row41_col20,#T_2a90a_row41_col22,#T_2a90a_row41_col23,#T_2a90a_row41_col24,#T_2a90a_row41_col25,#T_2a90a_row41_col27,#T_2a90a_row41_col28,#T_2a90a_row41_col29,#T_2a90a_row41_col30,#T_2a90a_row41_col31,#T_2a90a_row41_col32,#T_2a90a_row41_col33,#T_2a90a_row41_col34,#T_2a90a_row41_col35,#T_2a90a_row41_col36{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2a90a_row0_col3,#T_2a90a_row1_col29,#T_2a90a_row2_col8,#T_2a90a_row2_col10,#T_2a90a_row2_col27,#T_2a90a_row5_col20,#T_2a90a_row13_col35{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_2a90a_row0_col4,#T_2a90a_row8_col0,#T_2a90a_row11_col0,#T_2a90a_row32_col42,#T_2a90a_row36_col2{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_2a90a_row0_col5,#T_2a90a_row5_col42,#T_2a90a_row9_col4,#T_2a90a_row13_col4{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_2a90a_row0_col6,#T_2a90a_row4_col18,#T_2a90a_row7_col17,#T_2a90a_row8_col2,#T_2a90a_row18_col5,#T_2a90a_row21_col39,#T_2a90a_row26_col21,#T_2a90a_row26_col24,#T_2a90a_row32_col29,#T_2a90a_row34_col21{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_2a90a_row0_col8,#T_2a90a_row6_col21,#T_2a90a_row9_col5,#T_2a90a_row12_col5,#T_2a90a_row17_col5,#T_2a90a_row24_col8,#T_2a90a_row25_col1,#T_2a90a_row26_col33,#T_2a90a_row27_col5,#T_2a90a_row29_col19,#T_2a90a_row31_col2,#T_2a90a_row34_col32,#T_2a90a_row36_col30,#T_2a90a_row42_col18{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_2a90a_row0_col9,#T_2a90a_row0_col31,#T_2a90a_row2_col37,#T_2a90a_row2_col41,#T_2a90a_row4_col20,#T_2a90a_row16_col5,#T_2a90a_row24_col15,#T_2a90a_row26_col13,#T_2a90a_row26_col27,#T_2a90a_row28_col0,#T_2a90a_row31_col36,#T_2a90a_row31_col42,#T_2a90a_row32_col35,#T_2a90a_row42_col22{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_2a90a_row0_col10,#T_2a90a_row1_col35,#T_2a90a_row4_col6,#T_2a90a_row4_col8,#T_2a90a_row4_col27,#T_2a90a_row4_col30,#T_2a90a_row21_col35,#T_2a90a_row23_col21,#T_2a90a_row23_col35,#T_2a90a_row27_col21,#T_2a90a_row29_col6,#T_2a90a_row33_col0,#T_2a90a_row34_col27,#T_2a90a_row35_col6{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_2a90a_row0_col11,#T_2a90a_row0_col37,#T_2a90a_row0_col38,#T_2a90a_row0_col39,#T_2a90a_row0_col41,#T_2a90a_row1_col18,#T_2a90a_row4_col2,#T_2a90a_row11_col2,#T_2a90a_row26_col11,#T_2a90a_row26_col23,#T_2a90a_row28_col21,#T_2a90a_row33_col42,#T_2a90a_row35_col30{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_2a90a_row0_col12,#T_2a90a_row19_col35,#T_2a90a_row20_col34,#T_2a90a_row24_col22,#T_2a90a_row24_col27,#T_2a90a_row31_col5,#T_2a90a_row36_col27{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_2a90a_row0_col13,#T_2a90a_row10_col21,#T_2a90a_row12_col34,#T_2a90a_row20_col5,#T_2a90a_row21_col22,#T_2a90a_row29_col20,#T_2a90a_row29_col22,#T_2a90a_row33_col4,#T_2a90a_row36_col22{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_2a90a_row0_col14,#T_2a90a_row3_col5,#T_2a90a_row4_col25,#T_2a90a_row6_col5,#T_2a90a_row6_col29,#T_2a90a_row24_col32,#T_2a90a_row26_col0,#T_2a90a_row26_col1,#T_2a90a_row29_col18{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_2a90a_row0_col15,#T_2a90a_row4_col9,#T_2a90a_row4_col31,#T_2a90a_row10_col24,#T_2a90a_row18_col34,#T_2a90a_row22_col28,#T_2a90a_row23_col36,#T_2a90a_row33_col26,#T_2a90a_row36_col19,#T_2a90a_row42_col19,#T_2a90a_row42_col28{
#             background-color:  #d8dce2;
#             color:  #0

# %%
#Drop features that are highly correlated with each other (abs(corr) > 0.9) one by one until no correlated pairs left. 
#Hint: you may reuse code from Task_9 in HW_1 for automatic correlated pairs selection. (1.5 points)
numeric_features.remove('Value_USD')
corr_table = data[numeric_features].corr().stack().sort_values(ascending=False)
top_corr = corr_table[(corr_table != 1)&(corr_table >= 0.9)][::2]
features_to_drop = np.array(top_corr.index.get_level_values(0))
some_numeric_features = list(set(numeric_features)-set(features_to_drop))
print(some_numeric_features)
data[some_numeric_features].corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# ['Aggression', 'International Reputation', 'Balance', 'LongShots', 'Acceleration', 'Agility', 'Interceptions', 'Finishing', 'Positioning', 'Age', 'Dribbling', 'HeadingAccuracy', 'Strength', 'Stamina', 'ShortPassing', 'Crossing', 'Penalties', 'Weak Foot', 'ShotPower', 'LongPassing', 'Potential', 'Jersey Number', 'Curve', 'Skill Moves', 'Overall', 'Jumping', 'Vision', 'Reactions', 'Volleys', 'FKAccuracy', 'Composure']
# <style  type="text/css" >
# #T_29fd7_row0_col0,#T_29fd7_row1_col1,#T_29fd7_row2_col2,#T_29fd7_row3_col3,#T_29fd7_row4_col4,#T_29fd7_row5_col5,#T_29fd7_row6_col6,#T_29fd7_row7_col7,#T_29fd7_row8_col8,#T_29fd7_row9_col9,#T_29fd7_row10_col10,#T_29fd7_row11_col11,#T_29fd7_row12_col12,#T_29fd7_row13_col13,#T_29fd7_row14_col14,#T_29fd7_row15_col15,#T_29fd7_row16_col16,#T_29fd7_row17_col17,#T_29fd7_row18_col18,#T_29fd7_row19_col19,#T_29fd7_row20_col20,#T_29fd7_row21_col21,#T_29fd7_row22_col22,#T_29fd7_row23_col23,#T_29fd7_row24_col24,#T_29fd7_row25_col25,#T_29fd7_row26_col26,#T_29fd7_row27_col27,#T_29fd7_row28_col28,#T_29fd7_row29_col29,#T_29fd7_row30_col30{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_29fd7_row0_col1,#T_29fd7_row16_col6{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_29fd7_row0_col2,#T_29fd7_row0_col9,#T_29fd7_row27_col5{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_29fd7_row0_col3,#T_29fd7_row16_col0,#T_29fd7_row20_col1,#T_29fd7_row25_col13{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_29fd7_row0_col4,#T_29fd7_row6_col25,#T_29fd7_row9_col0,#T_29fd7_row17_col15,#T_29fd7_row18_col17,#T_29fd7_row29_col9{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_29fd7_row0_col5,#T_29fd7_row4_col11,#T_29fd7_row12_col30,#T_29fd7_row17_col3,#T_29fd7_row17_col14,#T_29fd7_row17_col26,#T_29fd7_row25_col6,#T_29fd7_row29_col20{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_29fd7_row0_col6,#T_29fd7_row14_col22,#T_29fd7_row15_col8,#T_29fd7_row23_col8{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }#T_29fd7_row0_col7,#T_29fd7_row13_col17,#T_29fd7_row15_col12,#T_29fd7_row20_col7{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_29fd7_row0_col8,#T_29fd7_row5_col24,#T_29fd7_row7_col20,#T_29fd7_row8_col20,#T_29fd7_row20_col26,#T_29fd7_row24_col11,#T_29fd7_row25_col24{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_29fd7_row0_col10,#T_29fd7_row8_col0,#T_29fd7_row11_col24,#T_29fd7_row16_col24,#T_29fd7_row19_col20,#T_29fd7_row29_col11{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_29fd7_row0_col11,#T_29fd7_row5_col8,#T_29fd7_row7_col29,#T_29fd7_row15_col4{
#             background-color:  #f7a688;
#             color:  #000000;
#         }#T_29fd7_row0_col12,#T_29fd7_row6_col13,#T_29fd7_row13_col2,#T_29fd7_row19_col8{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_29fd7_row0_col13,#T_29fd7_row14_col5,#T_29fd7_row14_col16,#T_29fd7_row18_col30,#T_29fd7_row26_col23{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_29fd7_row0_col14,#T_29fd7_row2_col15,#T_29fd7_row5_col14,#T_29fd7_row23_col30,#T_29fd7_row29_col30{
#             background-color:  #f6bea4;
#             color:  #000000;
#         }#T_29fd7_row0_col15,#T_29fd7_row13_col26,#T_29fd7_row22_col27{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_29fd7_row0_col16,#T_29fd7_row12_col25,#T_29fd7_row16_col17,#T_29fd7_row17_col19,#T_29fd7_row17_col24,#T_29fd7_row24_col2,#T_29fd7_row26_col9,#T_29fd7_row29_col17{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_29fd7_row0_col17,#T_29fd7_row4_col12,#T_29fd7_row9_col16,#T_29fd7_row21_col5{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_29fd7_row0_col18,#T_29fd7_row2_col19,#T_29fd7_row7_col11,#T_29fd7_row11_col28,#T_29fd7_row27_col19{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_29fd7_row0_col19,#T_29fd7_row5_col28,#T_29fd7_row13_col6,#T_29fd7_row13_col18,#T_29fd7_row15_col30,#T_29fd7_row26_col2,#T_29fd7_row28_col4,#T_29fd7_row30_col3,#T_29fd7_row30_col22{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_29fd7_row0_col20,#T_29fd7_row1_col26,#T_29fd7_row5_col0,#T_29fd7_row7_col0,#T_29fd7_row20_col10,#T_29fd7_row26_col11{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_29fd7_row0_col21,#T_29fd7_row4_col9{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_29fd7_row0_col22,#T_29fd7_row0_col25,#T_29fd7_row18_col20,#T_29fd7_row23_col0,#T_29fd7_row25_col11,#T_29fd7_row27_col15{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_29fd7_row0_col23,#T_29fd7_row10_col17,#T_29fd7_row17_col10,#T_29fd7_row17_col28,#T_29fd7_row17_col29,#T_29fd7_row22_col6,#T_29fd7_row24_col8,#T_29fd7_row25_col27{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_29fd7_row0_col24,#T_29fd7_row11_col15,#T_29fd7_row15_col6,#T_29fd7_row29_col24,#T_29fd7_row30_col2{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_29fd7_row0_col26,#T_29fd7_row17_col16{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_29fd7_row0_col27,#T_29fd7_row1_col20,#T_29fd7_row2_col16,#T_29fd7_row14_col20{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_29fd7_row0_col28,#T_29fd7_row4_col0,#T_29fd7_row12_col13,#T_29fd7_row14_col17,#T_29fd7_row19_col9,#T_29fd7_row20_col4,#T_29fd7_row24_col7,#T_29fd7_row27_col7{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_29fd7_row0_col29,#T_29fd7_row11_col27,#T_29fd7_row17_col5,#T_29fd7_row24_col29,#T_29fd7_row27_col29,#T_29fd7_row30_col1{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_29fd7_row0_col30,#T_29fd7_row4_col28,#T_29fd7_row6_col14,#T_29fd7_row19_col28,#T_29fd7_row26_col27{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_29fd7_row1_col0,#T_29fd7_row2_col17,#T_29fd7_row13_col9,#T_29fd7_row20_col29,#T_29fd7_row29_col1{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_29fd7_row1_col2,#T_29fd7_row1_col19,#T_29fd7_row3_col12,#T_29fd7_row4_col27,#T_29fd7_row6_col10,#T_29fd7_row11_col9,#T_29fd7_row16_col12,#T_29fd7_row17_col13,#T_29fd7_row20_col22,#T_29fd7_row22_col9,#T_29fd7_row23_col6{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_29fd7_row1_col3,#T_29fd7_row1_col6,#T_29fd7_row1_col15,#T_29fd7_row9_col26,#T_29fd7_row15_col1,#T_29fd7_row17_col9,#T_29fd7_row26_col12{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_29fd7_row1_col4,#T_29fd7_row7_col25,#T_29fd7_row17_col6{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_29fd7_row1_col5,#T_29fd7_row3_col1,#T_29fd7_row6_col4,#T_29fd7_row14_col25,#T_29fd7_row20_col6,#T_29fd7_row25_col14{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_29fd7_row1_col7,#T_29fd7_row6_col1,#T_29fd7_row6_col8,#T_29fd7_row9_col3,#T_29fd7_row9_col15,#T_29fd7_row12_col1,#T_29fd7_row20_col25,#T_29fd7_row21_col20,#T_29fd7_row23_col25{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_29fd7_row1_col8,#T_29fd7_row1_col10,#T_29fd7_row1_col25{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_29fd7_row1_col9,#T_29fd7_row11_col2,#T_29fd7_row18_col12,#T_29fd7_row24_col5,#T_29fd7_row28_col20{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_29fd7_row1_col11,#T_29fd7_row6_col3,#T_29fd7_row25_col18,#T_29fd7_row27_col17{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_29fd7_row1_col12,#T_29fd7_row3_col17,#T_29fd7_row14_col12{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_29fd7_row1_col13,#T_29fd7_row22_col25,#T_29fd7_row25_col15{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_29fd7_row1_col14,#T_29fd7_row2_col20,#T_29fd7_row6_col22,#T_29fd7_row24_col4{
#             backgroun

# %%
#Split data into train/test with some proportion (0.5 points)
# Просто выкинем строки с пропусками, их немного
data = data[data['Jersey Number'].notnull()]
target = 'Value_USD'
X, y = data[some_numeric_features].values, data[target].values
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=2)

# %%
#Train a model on train dataset, make predictions both for train and test. (0.5 points)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
lr.coef_
# Получилась куча признаков с маленькими весами
# Out:
# array([-1.91255150e+03,  6.45930032e+06,  9.46262862e+03, -7.90276655e+03,
#        -2.64579525e+03, -1.11584160e+04, -6.82321462e+03,  2.32455499e+04,
#         4.90717911e+03, -3.94509272e+05, -1.35044418e+04, -2.20077131e+03,
#        -1.61896726e+03,  1.76501737e+04, -1.44143265e+03, -9.79788803e+03,
#        -1.45767998e+04,  1.88264169e+04, -1.90715687e+04,  2.10808048e+03,
#        -6.08268733e+04, -4.74943930e+03, -9.17828152e+03,  1.97922921e+05,
#         4.45939741e+05, -5.88322984e+03,  1.03795805e+04,  3.88668666e+04,
#         7.85228581e+03,  1.56790295e+04, -3.39684503e+03])

# %%
#Measure the model quality in terms of RMSE in train and test samples, (0.5 points)
print(mean_squared_error(y_train, y_train_pred, squared=False))
print(mean_squared_error(y_test, y_test_pred, squared=False))
# Out:
# 3395117.5230593556
# 3748662.1912588533

# %%
# Видимо, стоило больше подумать при выборе признаков
# Попробуем уменьшить их количество l1 регуляризацией 
from sklearn.linear_model import LassoCV
regCV = LassoCV(cv=5, random_state=2).fit(X, y)
print(regCV.score(X_test, y_test))
print(mean_squared_error(y_train, regCV.predict(X_train), squared=False))
print(mean_squared_error(y_test, regCV.predict(X_test), squared=False))
regCV.coef_
# Модель выкинула несколько признаков. Качество при этом увеличилось совсем несильно.
# Out:
# 0.6030926952362334
# 3396819.8276042603
# 3748507.2151504788
# array([-3.46208556e+03,  6.37398479e+06,  8.95804811e+03, -6.42161185e+03,
#         0.00000000e+00, -1.15274856e+04, -6.14035183e+03,  2.21915999e+04,
#         4.32151033e+03, -3.68722094e+05, -1.07374514e+04, -1.61516519e+03,
#        -4.14754312e+03,  1.88814560e+04, -7.25626879e+02, -1.03873296e+04,
#        -1.40759577e+04,  0.00000000e+00, -1.86112406e+04,  5.52190545e+02,
#        -3.74861758e+04, -4.49379447e+03, -5.06878488e+03,  3.06471461e+04,
#         4.32192666e+05, -7.73386988e+03,  8.58919445e+03,  3.71101644e+04,
#         6.87222297e+03,  1.51960360e+04, -0.00000000e+00])

# %%
from sklearn.linear_model import Lasso
reg = Lasso(alpha=100000).fit(X_train, y_train)
print(reg.score(X_test, y_test))
reg.coef_
# Если еще уменьшать количество признаков l1 регуляризацией, качество начинает падать
# Out:
# 0.5942111502078072
# array([-2.31119757e+03,  5.52396849e+06,  7.09348339e+03, -6.52138362e+03,
#        -3.83868848e+02, -9.83476217e+03, -6.40748519e+03,  2.05112969e+04,
#         2.16783439e+03, -3.29985914e+05, -7.04110947e+03, -2.46833048e+03,
#        -8.80075690e+02,  1.34959983e+04, -0.00000000e+00, -7.87585111e+03,
#        -1.15787139e+04,  0.00000000e+00, -1.81286954e+04,  0.00000000e+00,
#        -0.00000000e+00, -4.32190143e+03, -5.30004953e+03,  0.00000000e+00,
#         4.09476730e+05, -4.27236579e+03,  1.11855535e+04,  4.00176177e+04,
#         9.30275782e+03,  1.25974816e+04, -0.00000000e+00])

# %% [markdown]
# Write a short report about the work done(1 point). Why did you take these particular features?
#
# **Я решил посмотреть все числовые признаки. Возможно, в категориальных тоже есть весьма полезные. Но у нас же задача покрутить признаки и регрессию, а не получить максимальный скор.**
#
# Can you find a logical explanation for high correlation of some of your features?
#
# **Посмотрим на эти признаки:**

# %%
top_corr
# Думаю, все это игровые показатели, которые зависят от физических данных спортсменов. И коррелированные показатели
#зависят от одних и тех же физических данных.
# Out:
# SlidingTackle   StandingTackle    0.974659
# GKDiving        GKReflexes        0.973320
# GKHandling      GKDiving          0.970280
#                 GKReflexes        0.970264
# GKReflexes      GKPositioning     0.970130
# GKPositioning   GKDiving          0.969864
#                 GKHandling        0.969408
# GKKicking       GKReflexes        0.966337
# GKDiving        GKKicking         0.965685
# GKKicking       GKHandling        0.965239
#                 GKPositioning     0.964336
# StandingTackle  Interceptions     0.941471
# BallControl     Dribbling         0.938942
# SlidingTackle   Interceptions     0.928282
# SprintSpeed     Acceleration      0.921928
# Special         BallControl       0.912107
# BallControl     ShortPassing      0.911451
# Special         ShortPassing      0.906729
# Marking         StandingTackle    0.906541
# dtype: float64

# %% [markdown]
# Are you satisfied with the quality of predictions? etc.
#
# **Я вобщем-то и не ожидал, что по таким данным можно получить высокую точность. Думаю, с кат. фичами реально выжать скор где-то 0.7 - 0.8**
#
# **Кстати, у нас интересная целевая переменная. Она не точная, а округленная. Чаще всего стоимость меньше 100К, но высокие суммы округлены с точностью 0.5М. Что это значит и что делать? Как минимум, не ожидать высокой точности при предсказании больших сумм.**
#
# **А еще кстати, Value иногда равна 0. Но это означает отсутствие сделок, а не нулевую стоимость. Может лучше было выкинуть такие строки?**
